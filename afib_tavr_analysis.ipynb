# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 20 17:33:09 2020

@author: Wasiq
@author: Sud
"""
# import win32file
import sys
# NOTE: Need to rename a sub-package to get around some weird versioning issues
# Might need to double-check this before running on a remote cluster. 
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# Now back to regular imports
import matplotlib.pyplot as plt
import statistics
import missingpy
import scipy as sp
import IPython
import sklearn
import sys
import pandas as pd
import numpy as np
import time

# %%
from sklearn.model_selection import train_test_split
from missingpy import KNNImputer
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import ParameterGrid
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import RandomizedSearchCV
from multiprocessing import Process
from multiprocessing import Pool

# %%
# win32file._setmaxstdio(2048)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 400)
POAF=pd.read_csv("FINAL_PROCESSED_DATA_WS.csv")
POAF_X=POAF.iloc[:,0:396]
POAF_Y=POAF.iloc[:,396]

# %%
# "Labels" is a variable of column names
labels=POAF_X.columns.values 
# Split into training and testing sets
X_train_set, X_test_set, Y_train_set, Y_test_set=train_test_split(POAF_X, POAF_Y, stratify=POAF_Y, random_state=69)
# Normalize the first 50 columns (these are the ones with continuous data, all others are categorical)
for col in X_test_set.columns[0:50]:
    X_test_set[col]=(X_test_set[col]-X_train_set[col].mean())/X_train_set[col].std()
    X_train_set[col]=(X_train_set[col]-X_train_set[col].mean())/X_train_set[col].std()

# %%
X_train_set_np=np.array(X_train_set)
X_test_set_np=np.array(X_test_set)
Y_train_set_np=np.array(Y_train_set)
Y_test_set_np=np.array(Y_test_set)
skf=StratifiedKFold(n_splits=5) # random_state=69, shuffle=True
n=[]

# %%
def score_model_RFE(model, params, cv=skf, features_to_select= n):
    smoter=SMOTE(random_state=42)

    scores=[]
    
    for train_fold_index, val_fold_index in cv.split(X_train_set_np, Y_train_set_np):
        X_train_fold, y_train_fold=X_train_set_np[train_fold_index], Y_train_set_np[train_fold_index]
        X_val_fold, y_val_fold=X_train_set_np[val_fold_index], Y_train_set_np[val_fold_index]
        X_train_fold_upsample, y_train_fold_upsample=smoter.fit_resample(X_train_fold, y_train_fold)
        RF=RFE(model(**params, n_jobs=-1),n_features_to_select= features_to_select,step=1, verbose=0).fit(X_train_fold_upsample, y_train_fold_upsample)
        score=roc_auc_score(y_val_fold, RF.predict(X_val_fold))
        scores.append(score)
        
    return np.array(scores)

# %%
# Set the amount of combinations to perform
max_depth=[1]
min_samples_split= [2] #[0.6, 2, 4, 5, 10, 20, 30]
min_samples_leaf= [5] #[1,5,20,25,30,40,50,60]
RFE_features_to_select= list(range(1, 5)) #list(range(1,396))
n_estimators= 10 #500

def RFE_model(n):
    score_tracker=[]
    for c in min_samples_leaf:
        for b in min_samples_split:
            for a in max_depth:
                print("Features", n)
                print("Min samples", c)
                print("min samples split", b)
                print("max depth", a)
                #start = time.time()
                example_params={'n_estimators': n_estimators, 'max_depth': a, 'min_samples_split': b, 'min_samples_leaf': c}
                example_params['roc_auc']=score_model_RFE(RandomForestClassifier, example_params, cv=skf, features_to_select= n).mean()
                example_params['n_features_selected']=n
                #end = time.time()
                #print("[*******] Processing Time: ", end - start, "sec")
                score_tracker.append(example_params)
    return np.array(score_tracker)

# %%
# Run non-parallized analysis
result = []
for i in range(1,5):
    start = time.time()
    result.append(RFE_model(i))
    end = time.time()
    print("[*******] Processing Time: ", end - start, "sec")
    print("Result: \n", result, "\n \n")
# Out:
# Features 1
# Min samples 5
# min samples split 2
# max depth 1
# [*******] Processing Time:  55.35209083557129 sec
# Result:
#  [array([{'n_estimators': 10, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5, 'roc_auc': 0.531164205502402, 'n_features_selected': 1}],
#       dtype=object)]
#
#
# Features 2
# Min samples 5
# min samples split 2
# max depth 1
# [*******] Processing Time:  58.29740381240845 sec
# Result:
#  [array([{'n_estimators': 10, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5, 'roc_auc': 0.531164205502402, 'n_features_selected': 1}],
#       dtype=object), array([{'n_estimators': 10, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5, 'roc_auc': 0.5090537219647245, 'n_features_selected': 2}],
#       dtype=object)]
#
#
# Features 3
# Min samples 5
# min samples split 2
# max depth 1
# [*******] Processing Time:  60.024736404418945 sec
# Result:
#  [array([{'n_estimators': 10, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5, 'roc_auc': 0.531164205502402, 'n_features_selected': 1}],
#       dtype=object), array([{'n_estimators': 10, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5, 'roc_auc': 0.5090537219647245, 'n_features_selected': 2}],
#       dtype=object), array([{'n_estimators': 10, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5, 'roc_auc': 0.5340820516466767, 'n_features_selected': 3}],
#       dtype=object)]
#
#
# Features 4
# Min samples 5
# min samples split 2
# max depth 1
# Exception ignored in: <Finalize object, dead>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 88, in _cleanup
#     unregister(name, "semaphore")
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py", line 151, in unregister
#     self._send('UNREGISTER', name, rtype)
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py", line 154, in _send
#     self.ensure_running()
#   File "/opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py", line 80, in ensure_running
#     return
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#       3 for i in range(1,5):
#       4     start = time.time()
# ----> 5     result.append(RFE_model(i))
#       6     end = time.time()
#       7     print("[*******] Processing Time: ", end - start, "sec")
#
# Input In [47], in RFE_model(n)
#      17 #start = time.time()
#      18 example_params={'n_estimators': n_estimators, 'max_depth': a, 'min_samples_split': b, 'min_samples_leaf': c}
# ---> 19 example_params['roc_auc']=score_model_RFE(RandomForestClassifier, example_params, cv=skf, features_to_select= n).mean()
#      20 example_params['n_features_selected']=n
#      21 #end = time.time()
#      22 #print("[*******] Processing Time: ", end - start, "sec")
#
# Input In [46], in score_model_RFE(model, params, cv, features_to_select)
#       8 X_val_fold, y_val_fold=X_train_set_np[val_fold_index], Y_train_set_np[val_fold_index]
#       9 X_train_fold_upsample, y_train_fold_upsample=smoter.fit_resample(X_train_fold, y_train_fold)
# ---> 10 RF=RFE(model(**params, n_jobs=-1),n_features_to_select= features_to_select,step=1, verbose=0).fit(X_train_fold_upsample, y_train_fold_upsample)
#      11 score=roc_auc_score(y_val_fold, RF.predict(X_val_fold))
#      12 scores.append(score)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_rfe.py:235, in RFE.fit(self, X, y, **fit_params)
#     215 def fit(self, X, y, **fit_params):
#     216     """Fit the RFE model and then the underlying estimator on the selected features.
#     217
#     218     Parameters
#    (...)
#     233         Fitted estimator.
#     234     """
# --> 235     return self._fit(X, y, **fit_params)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_rfe.py:296, in RFE._fit(self, X, y, step_score, **fit_params)
#     293 if self.verbose > 0:
#     294     print("Fitting estimator with %d features." % np.sum(support_))
# --> 296 estimator.fit(X[:, features], y, **fit_params)
#     298 # Get importance and rank them
#     299 importances = _get_feature_importances(
#     300     estimator,
#     301     self.importance_getter,
#     302     transform_func="square",
#     303 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File /opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File /opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File /opt/anaconda3/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File /opt/anaconda3/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File /opt/anaconda3/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File /opt/anaconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
# Run the parallelized analysis
p=Pool()
result= p.map(RFE_model, range(1,5))
LIST_OF_RESULTS=[]
for i in range(0,len(result)):
    for t in (0,(result[i].size-1)):
        LIST_OF_RESULTS.append(result[i][t])

# %%
### Cells below contain original code / old working scripts ###

# %%
num_features = 5

# Pick the parameters
example_params={'n_estimators': 11, 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 5}

# Run the score
start = time.time()
example_params['roc_auc']=score_model_RFE(RandomForestClassifier, example_params, cv=skf, features_to_select= 5).mean()
end = time.time()
print("Processing Time: ", end - start, "sec")

# Tag the results with the number of features
example_params['n_features_selected']=num_features

# Print output
print(example_params['roc_auc'])

# %%
# win32file._setmaxstdio(2048)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 400)
POAF=pd.read_csv("FINAL_PROCESSED_DATA_WS.csv")
POAF_X=POAF.iloc[:,0:396]
POAF_Y=POAF.iloc[:,396]
labels=POAF_X.columns.values
X_train_set, X_test_set, Y_train_set, Y_test_set=train_test_split(POAF_X, POAF_Y, stratify=POAF_Y, random_state=69)
for col in X_test_set.columns[0:50]:
    X_test_set[col]=(X_test_set[col]-X_train_set[col].mean())/X_train_set[col].std()
    X_train_set[col]=(X_train_set[col]-X_train_set[col].mean())/X_train_set[col].std()

X_train_set_np=np.array(X_train_set)
X_test_set_np=np.array(X_test_set)
Y_train_set_np=np.array(Y_train_set)
Y_test_set_np=np.array(Y_test_set)
skf=StratifiedKFold(n_splits=5, random_state=69)

n=[]

def score_model_RFE(model, params, cv=skf, features_to_select= n):
    smoter=SMOTE(random_state=42)

    scores=[]
    
    for train_fold_index, val_fold_index in cv.split(X_train_set_np, Y_train_set_np):
        X_train_fold, y_train_fold=X_train_set_np[train_fold_index], Y_train_set_np[train_fold_index]
        X_val_fold, y_val_fold=X_train_set_np[val_fold_index], Y_train_set_np[val_fold_index]
        X_train_fold_upsample, y_train_fold_upsample=smoter.fit_resample(X_train_fold, y_train_fold)
        RF=RFE(model(**params, n_jobs=-1),n_features_to_select= features_to_select,step=1, verbose=3).fit(X_train_fold_upsample, y_train_fold_upsample)
        score=roc_auc_score(y_val_fold, RF.predict(X_val_fold))
        scores.append(score)
        
    return np.array(scores)

max_depth=[1]
min_samples_split=[0.6, 2, 4, 5, 10, 20, 30]
min_samples_leaf=[1,5,20,25,30,40,50,60]
RFE_features_to_select= list(range(1,396))
n_estimators=500

def RFE_model(n):
    score_tracker=[]
    for c in min_samples_leaf:
        for b in min_samples_split:
            for a in max_depth:
                print("Features", n)
                print("Min samples", c)
                print("min samples split", b)
                print("max depth", a)
                example_params={'n_estimators': n_estimators, 'max_depth': a, 'min_samples_split': b, 'min_samples_leaf': c}
                example_params['roc_auc']=score_model_RFE(RandomForestClassifier, example_params, cv=skf, features_to_select= n).mean()
                example_params['n_features_selected']=n
                score_tracker.append(example_params)
    return np.array(score_tracker)

if __name__=='__main__':
    p=Pool()
    result= p.map(RFE_model, RFE_features_to_select)
    LIST_OF_RESULTS=[]
    for i in range(0,len(result)):
        for t in (0,(result[i].size-1)):
            LIST_OF_RESULTS.append(result[i][t])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 win32file._setmaxstdio(2048)
#       2 pd.set_option('display.max_rows', 1000)
#       3 pd.set_option('display.max_columns', 400)
#
# NameError: name 'win32file' is not defined
